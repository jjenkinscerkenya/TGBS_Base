# %%
import pandas as pd
from pathlib import Path
from matplotlib import pyplot as plt

# %%
from tgbs_rs.config.config import TABLES_DIR
from tgbs_rs.visualization.plots import plot_annual_total_precipitation, plot_monthly_total_precipitation

# %%
csv_paths = {
    "annual_precipitation": TABLES_DIR / "tgbs_chirps_v3_rnl_annual_rainfall_total_2014_2025.csv",
    "monthly_precipitation": TABLES_DIR / "tgbs_chirps_v3_rnl_monthly_rainfall_total_2018_2025.csv",
}

# %%
annual_df = pd.read_csv(csv_paths["annual_precipitation"])
monthly_df = pd.read_csv(csv_paths["monthly_precipitation"])

plot_annual_total_precipitation(annual_df, figsize=(11, 5))
plot_monthly_total_precipitation(monthly_df)
plt.show()
