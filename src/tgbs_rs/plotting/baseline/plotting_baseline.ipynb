# %%
from tgbs_rs.plotting.baseline.plotting_baseline import plot_baseline_panels_from_rasters, plot_forest_panels_from_rasters
from tgbs_rs.config.config import RASTER_DIR

# %%
fig, ax = plot_forest_panels_from_rasters(RASTER_DIR)

# %%
fig, ax = plot_baseline_panels_from_rasters(RASTER_DIR)
