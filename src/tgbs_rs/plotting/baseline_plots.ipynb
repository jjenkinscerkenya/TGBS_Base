# %%
import matplotlib as plt
from tgbs_rs.plotting.plotting_baseline import plot_baseline_panels_from_rasters, plot_forest_cover_2000_from_raster, plot_forest_loss_years_from_raster

# %%
fig, ax = plot_baseline_panels_from_rasters(raster_dir=r"C:\Users\harre\Repos\CERK\TGBS_Base\outputs\raster")
fig
